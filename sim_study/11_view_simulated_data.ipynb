# %%
from config import *
from pandas import read_csv
import plotnine as pn

# %%
true_results = read_csv(
    os.path.join(RESULTS_DIR, "sim_output.csv"),
    dtype={
        "age": "string"
    },
    parse_dates=[2],
    index_col=0
)
true_results.describe()
# Out:
#                 sim     incidence    prevalence     num_tests         theta  \
# count  88200.000000  88200.000000  88200.000000  88200.000000  8.820000e+04
# mean      49.500000      0.001189      0.021142   2499.500000  1.978843e-05
# std       28.866234      0.001492      0.026005   1367.772932  1.950666e-05
# min        0.000000      0.000004      0.000044    853.000000  8.170795e-08
# 25%       24.750000      0.000248      0.003389   1609.000000  4.227664e-06
# 50%       49.500000      0.000686      0.012955   1998.500000  1.363851e-05
# 75%       74.250000      0.001552      0.028917   3578.000000  2.758233e-05
# max       99.000000      0.019214      0.298222   4960.000000  9.770912e-05
#
#        obs_positives  obs_prevalence
# count   88200.000000    88200.000000
# mean       48.020748        0.021134
# std        67.944882        0.026222
# min         0.000000        0.000000
# 25%         7.000000        0.003427
# 50%        26.000000        0.012856
# 75%        62.000000        0.029032
# max      1194.000000        0.325909

# %%
(
    pn.ggplot(true_results.reset_index(), pn.aes("date", "incidence", group="sim")) +
    pn.geom_line() +
    pn.scale_y_log10() +
    pn.facet_wrap("~age")
)
# Out:
# <ggplot: (2978211366383)>

# %%
(
    pn.ggplot(true_results.reset_index(), pn.aes("date", "prevalence", group="sim")) +
    pn.geom_line() +
    pn.scale_y_log10() +
    pn.facet_wrap("~age")
)
# Out:
# <ggplot: (-9223369058634096661)>

# %%
(
    pn.ggplot(true_results[true_results["sim"] < 9], pn.aes("date", "prevalence", colour = "age")) +
    pn.geom_line() +
    pn.geom_point(pn.aes(y="obs_prevalence")) +
    pn.facet_wrap("~sim",scales="free_y")
)
# Out:
# /home/jbb50/PhD_work/SEIR_model/.venv/lib64/python3.6/site-packages/plotnine/facets/facet.py:393: PlotnineWarning: If you need more space for the x-axis tick text use ... + theme(subplots_adjust={'wspace': 0.25}). Choose an appropriate value for 'wspace'.
# <ggplot: (2978211397647)>

# %%
(
    pn.ggplot(true_results[true_results["sim"] < 9], pn.aes("date", "prevalence", colour = "age")) +
    pn.geom_line() +
    pn.facet_wrap("~sim",scales="free_y")
)
# Out:
# /home/jbb50/PhD_work/SEIR_model/.venv/lib64/python3.6/site-packages/plotnine/facets/facet.py:393: PlotnineWarning: If you need more space for the x-axis tick text use ... + theme(subplots_adjust={'wspace': 0.25}). Choose an appropriate value for 'wspace'.
# <ggplot: (2978220502592)>
